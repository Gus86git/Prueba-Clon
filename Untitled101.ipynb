# %% [markdown]
# <a href="https://colab.research.google.com/github/Gus86git/Prueba-Clon/blob/main/Untitled101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title 🎙️ Iniciar Clonador de Voz (Qwen + Fish Speech)
# @markdown Ejecuta esta celda para instalar todo e iniciar la interfaz de Gradio.

import os

# 1. Clonar el repositorio (Reemplaza con TU URL de GitHub si es necesario)
REPO_URL = "https://github.com/TU_USUARIO/Clonador.git" # <--- CAMBIA ESTO
REPO_NAME = "Clonador"

if not os.path.exists(REPO_NAME):
    print(f"Clonando repositorio {REPO_URL}...")
    # !git clone {REPO_URL}
else:
    print("El repositorio ya existe, actualizando...")
    # %cd {REPO_NAME}
    # !git pull
    # %cd ..

# %cd {REPO_NAME}

# 2. Instalar dependencias
print("Instalando dependencias (esto puede tomar 1-2 minutos)...")
# !pip install -r requirements.txt
# !pip install -q huggingface_hub

# 3. Ejecutar la aplicación
print("Iniciando la aplicación...")
# !python app.py
